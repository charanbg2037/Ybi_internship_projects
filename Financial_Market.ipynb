# %% [markdown]
# <a href="https://colab.research.google.com/github/charanbg2037/Ybi_internship_projects/blob/main/Financial_Market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**FINANCIAL MARKET NEWS PREDICTION**

# %% [markdown]
# ##**Objective**
#
# The objective of "Financial Market News Prediction" is to leverage predictive analytics and machine learning to forecast market movements, asset prices, and financial events based on the analysis of news and information relevant to the financial markets. This serves several key purposes:
#
# Risk Management: To help investors, traders, and financial institutions anticipate and manage risks associated with market fluctuations, economic events, or news-driven volatility.
#
# Trading Strategy Development: To inform trading decisions by providing insights into potential market trends and opportunities, allowing for the development of profitable trading strategies.
#
# Investor Decision Support: To assist investors in making informed decisions about buying or selling assets, managing portfolios, and optimizing their financial positions.
#
# Market Sentiment Analysis: To gauge market sentiment and investor behavior by analyzing news sentiment, social media, and other sources, aiding in understanding market psychology.
#
# Algorithmic Trading: To support automated trading systems that execute trades based on predefined criteria, incorporating news-based predictions for faster and data-driven trading.
#
# Regulatory Compliance: To help financial institutions comply with regulations related to market manipulation, insider trading, and information disclosure.

# %% [markdown]
# ##**Data Source**
#
# The dataset for this project were taken from "Ybi Foundation" github account

# %% [markdown]
# ##**Import Library**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##**Import Data**

# %%
data = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Financial%20Market%20News.csv', encoding = 'ISO-8859-1')
data
# Out:
#             Date  Label                                             News 1  \
# 0     01-01-2010      0           McIlroy's men catch cold from Gudjonsson
# 1     02-01-2010      0               Warning from history points to crash
# 2     03-01-2010      0      Comment: Why Israel's peaceniks feel betrayed
# 3     04-01-2010      1             £750,000-a-goal Weah aims parting shot
# 4     05-01-2010      1  Leeds arrive in Turkey to the silence of the fans
# ...          ...    ...                                                ...
# 4096  20-03-2021      0  Barclays and RBS shares suspended from trading...
# 4097  21-03-2021      1  2,500 Scientists To Australia: If You Want To ...
# 4098  22-03-2021      1                   Explosion At Airport In Istanbul
# 4099  23-03-2021      1  Jamaica proposes marijuana dispensers for tour...
# 4100  24-03-2021      1  A 117-year-old woman in Mexico City finally re...
#
#                                                  News 2  \
# ...

# %% [markdown]
# ##**Describe Data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4101 entries, 0 to 4100
# Data columns (total 27 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4101 non-null   object
#  1   Label    4101 non-null   int64
#  2   News 1   4101 non-null   object
#  3   News 2   4101 non-null   object
#  4   News 3   4101 non-null   object
#  5   News 4   4101 non-null   object
#  6   News 5   4101 non-null   object
#  7   News 6   4101 non-null   object
#  8   News 7   4101 non-null   object
#  9   News 8   4101 non-null   object
#  10  News 9   4101 non-null   object
#  11  News 10  4101 non-null   object
#  12  News 11  4101 non-null   object
#  13  News 12  4101 non-null   object
#  14  News 13  4101 non-null   object
#  15  News 14  4101 non-null   object
#  16  News 15  4101 non-null   object
#  17  News 16  4101 non-null   object
#  18  News 17  4101 non-null   object
#  19  News 18  4101 non-null   object
# ...

# %%
data.describe()
# Out:
#              Label
# count  4101.000000
# mean      0.528164
# std       0.499267
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
data.shape
# Out:
# (4101, 27)

# %%
data.columns
# Out:
# Index(['Date', 'Label', 'News 1', 'News 2', 'News 3', 'News 4', 'News 5',
#        'News 6', 'News 7', 'News 8', 'News 9', 'News 10', 'News 11', 'News 12',
#        'News 13', 'News 14', 'News 15', 'News 16', 'News 17', 'News 18',
#        'News 19', 'News 20', 'News 21', 'News 22', 'News 23', 'News 24',
#        'News 25'],
#       dtype='object')

# %%
' '.join(str(x) for x in data.iloc[0:, 2:27])
# Out:
# 'News 1 News 2 News 3 News 4 News 5 News 6 News 7 News 8 News 9 News 10 News 11 News 12 News 13 News 14 News 15 News 16 News 17 News 18 News 19 News 20 News 21 News 22 News 23 News 24 News 25'

# %%
news=[]
for rows in range(0, len(data.index)):
  news.append(' '.join(str(x) for x in data.iloc[rows, 2:27]))

# %%
data.head()
# Out:
#          Date  Label                                             News 1  \
# 0  01-01-2010      0           McIlroy's men catch cold from Gudjonsson
# 1  02-01-2010      0               Warning from history points to crash
# 2  03-01-2010      0      Comment: Why Israel's peaceniks feel betrayed
# 3  04-01-2010      1             £750,000-a-goal Weah aims parting shot
# 4  05-01-2010      1  Leeds arrive in Turkey to the silence of the fans
#
#                                        News 2  \
# 0                       Obituary: Brian Walsh
# 1              Investors flee to dollar haven
# 2  Court deals blow to seizure of drug assets
# 3            Newcastle pay for Fletcher years
# 4     One woman's vision offers loan lifeline
#
#                                             News 3  \
# 0       Workplace blues leave employers in the red
# 1                      Banks and tobacco in favour
# 2                       An ideal target for spooks
# ...

# %%
news[400]
# Out:
# "Blair refuses to reappoint audit commission head Green light for clever speed cameras Feeling good, doing better Free period 14-Aug Mind games Comedy: Adam Bloom Zehetmair Quartet Theatre: Imaginary Prisons Jazz: Brecker Bros/Joshua Redman Comedy: Adam Hills Theatre: Romeo and Juliet Pop: Jamiroquai Classical: Les Troyens, Part 1 Theatre: A Dark River Comedy: Trev and Simon Cutting cash machine fees may cost 'big four' £200m Opera: Salzburg festival Theatre: Falsettoland Pop: Primal Scream Inflation fall exceeds expectations Uk pension schemes under-funded by millions New database for unclaimed assets West Ham United Tottenham Hotspur"

# %%
x = news

# %% [markdown]
# ##**Define Target Variable (y) and Feature Variables (X):**

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(lowercase = True, ngram_range=(1,1))

# %%
x = cv.fit_transform(x)

# %%
x.shape
# Out:
# (4101, 48527)

# %%
y = data['Label']

# %%
y.shape
# Out:
# (4101,)

# %% [markdown]
# ##**Train Test Split**

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.3, random_state = 777)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((2870, 48527), (1231, 48527), (2870,), (1231,))

# %% [markdown]
# ##**Modeling**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ##**Prediction**

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %% [markdown]
# ##**Model Evaluation**

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
acc = accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.5255889520714866

# %%
cun = confusion_matrix(y_test, y_pred)
print(cun)
# Out:
# [[216 347]
#  [237 431]]

# %%
cal = classification_report(y_test, y_pred)
print(cal)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.38      0.43       563
#            1       0.55      0.65      0.60       668
#
#     accuracy                           0.53      1231
#    macro avg       0.52      0.51      0.51      1231
# weighted avg       0.52      0.53      0.52      1231

# %% [markdown]
# ##**Explaination**
#
# I have developed a Random Forest Classifier model for financial market news prediction with an accuracy of 0.54%. While the accuracy might seem low, it's important to consider that financial market prediction is an intricate and challenging task. This model lays the foundation for further improvement and fine-tuning. The advantage of Random Forest is that it can capture complex relationships in data and offer insights into market trends. To enhance its accuracy, you can refine feature selection, incorporate more extensive and relevant data sources, and fine-tune model parameters. With continued effort, this model has the potential to become a valuable tool for making informed financial market decisions and navigating the complexities of the financial world.
